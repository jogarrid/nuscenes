# %% [markdown]
# <a href="https://colab.research.google.com/github/jogarrid/nuscenes/blob/master/nuscenesVanillaLSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # > IMPLEMENTATION OF VANILLA LSTM MODEL DESCRIBED ON SOCIAL LSTM PAPER TO TRAJECTORY DATA IN THE NUSCENES DATASET.
# COMPARISON BETWEEN PERFORMANCE (MSE) BETWEEN A LINNEAR PREDICTOR AND THE LSTM PREDICTOR

# %%
import numpy as np
from google.colab import drive
drive.mount('/content/gdrive')
map_data_split = np.load('/content/gdrive/My Drive/map_data_split.npy')  #scenes x partitions x instances x time_steps x 2
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import os
import pickle
import numpy as np
import random

class DataLoader():

    def __init__(self, batch_size=50, seq_length=5, datasets=list(range(90)), force_preprocessing = True, testing=False):
        '''
        Initialiser function for the DataLoader class
        params:
        batch_size : Size of the mini-batch
        seq_length : RNN sequence length
        '''

        self.used_data_dirs = datasets

        # Data directory where the pre-processed pickle file resides
        self.data_dir = '/content/gdrive/My Drive/vanillaData/'

        # Store the batch size and the sequence length arguments
        self.batch_size = batch_size
        self.seq_length = seq_length

        # Define the path of the file in which the data needs to be stored
        data_file = os.path.join(self.data_dir, "trajectories.cpkl")

        self.testing = testing
        
        # If the file doesn't exist already or if forcePreProcess is true
        if not(os.path.exists(data_file)) or force_preprocessing:
            print("Creating pre-processed data from raw data")
            # Preprocess the data from the csv files
            self.preprocess(self.used_data_dirs, data_file)

        # Load the data from the pickled file
        self.load_preprocessed(data_file)
        # Reset all the pointers
        self.reset_batch_pointer()

    def preprocess(self, scenes, data_file):
        '''
        scenes : List of scene indixes to be loaded
        data_file : The file into which all the pre-processed data needs to be stored
        '''
        # all_ins_data would be a dictionary with mapping from each instance to their
        # trajectories given by matrix 3 x numPoints with each column
        # in the order x, y, frameId

        all_ins_data = {}
        dataset_indices = []
        current_ins = 0
      
        # where each column is a (frameId, instance_Id, y, x) vector
 
        data_all = np.load('/content/gdrive/My Drive/map_data_split.npy')  #scenes x partitions x instances x time_steps x 2
        data_all = data_all[scenes]
        
        frame_Id = 0
        instance_Id = 0
        data = []

        means = []
        stds = []
        indexes = []
        self.mean_std = []
        for scene_ix in range(data_all.shape[0]):
          for partition_ix in range(data_all.shape[1]):
            part = data_all[scene_ix, partition_ix]
            for instance_ix in range(part.shape[0]):
              traj_x = data_all[scene_ix, partition_ix][instance_ix, :, 0]
              traj_y = data_all[scene_ix, partition_ix][instance_ix, :, 1]

              if(~np.any(traj_x == -999) and ~np.any(traj_y == -999)):
                mean_x = np.mean(traj_x[0:4])
                mean_y = np.mean(traj_y[0:4])
                std_x = np.std(traj_x[0:4])
                std_y = np.std(traj_y[0:4])
                #if(std_x > threshold or std_y>threshold):

                traj_x = (traj_x - mean_x)/(std_x+0.5)
                traj_y = (traj_y - mean_y)/(std_y+0.5)
                means.append([mean_x, mean_y])
                stds.append([std_x, std_y])

                indexes.append([scene_ix, partition_ix, instance_ix])

                for time_ix in range(traj_x.shape[0]):
                  data.append([frame_Id, instance_Id, traj_x[time_ix], traj_y[time_ix]])
                self.mean_std.append([[mean_x, std_x], [mean_y, std_y], [scene_ix, partition_ix, instance_ix]])
                
                instance_Id += 1 
            frame_Id += 1
        data = np.array(data).T

        # Get the number of pedestrians in the current dataset
        numIns = np.size(np.unique(data[1, :]))  #an instance can be a car, a pedestrian, a bycicle, etc...

        for instance_Id in range(numIns):
            # Extract trajectory of the current instance
            traj = data[:, data[1, :] == instance_Id]
                        
            # Format it as (x, y, frameId)
            traj = traj[[2, 3, 0], :]

            # Store this in the dictionary
            all_ins_data[instance_Id] = traj

            mean_std = self.mean_std[instance_Id]
            mean_x = mean_std[0][0]
            std_x = mean_std[0][1]
            mean_y = mean_std[1][0]
            std_y = mean_std[1][1]
            
            traj_r = np.zeros(traj.shape)
            traj_r[0,:] =  traj[0,:] *(std_x +0.5)+mean_x
            traj_r[1,:] = traj[1,:] *(std_y +0.5)+mean_y
            index = indexes[instance_Id]

        # Current dataset done
        dataset_indices.append(current_ins+numIns)

        # The complete data is a tuple of all intance data, and dataset ped indices
        complete_data = (all_ins_data, dataset_indices)
        # Store the complete data into the pickle file
        f = open(data_file, "wb")
        pickle.dump(complete_data, f, protocol=2)
        f.close()

    def load_preprocessed(self, data_file):
        '''
        Function to load the pre-processed data into the DataLoader object
        params:
        data_file : The path to the pickled data file
        '''
        # Load data from the pickled file
        f = open(data_file, "rb")
        self.raw_data = pickle.load(f)
        f.close()

        # Get the data from the pickle file
        all_ins_data = self.raw_data[0]

        # Construct the data with sequences(or trajectories) longer than seq_length
        self.data = []
        counter = 0

        # For each instance in the data
        
        for instance_Id in all_ins_data:
            # Extract his trajectory
            traj = all_ins_data[instance_Id]
            
            # If the length of the trajectory is greater than seq_length 
            if traj.shape[1] > (self.seq_length):
                self.data.append(traj[[0, 1], :].T)
                counter += 1

        #shuffle the data (if training) so all trajectories belonging to an instance won´t be in the same batch in different epoch
        indexes = np.arange(len(self.data))
        self.data = np.array(self.data)
        self.mean_std = np.array(self.mean_std)
        
        #if training, shuffle the data
        if(not self.testing): 
          np.random.shuffle(indexes)
        
        self.data = self.data[indexes]
        self.mean_std = self.mean_std[indexes]
                
        # Calculate the number of batches (each of batch_size) in the data
        self.num_batches = int(counter / self.batch_size)

        
    def next_batch(self):
        '''
        Function to get the next batch of points
        '''
        # List of source and target data for the current batch
        x_batch = []
        y_batch = []
        # For each sequence in the batch
        for i in range(self.batch_size):
            # Extract the trajectory of the pedestrian pointed out by self.pointer
            traj = self.data[self.pointer]
            mean_std = self.mean_std[self.pointer]
            idx = 0 
            # Append the trajectory from idx until seq_length into source and target data
            x_batch.append(np.copy(traj[idx:idx+self.seq_length, :]))
            y_batch.append(np.copy(traj[idx+1:idx+self.seq_length+1, :]))
            self.tick_batch_pointer()

        return x_batch, y_batch, mean_std

    def tick_batch_pointer(self):
        '''
        Advance the data pointer
        '''
      
        #TODO: randomize data as you set the pointer to 0 so that you don´t train always over the same batches
        self.pointer += 1
        if (self.pointer >= len(self.data)):
            self.pointer = 0
            indexes = np.arange(len(self.data))
            self.data = np.array(self.data)
            self.mean_std = np.array(self.mean_std)

            #if training, shuffle the data
            if(not self.testing): 
              np.random.shuffle(indexes)

            self.data = self.data[indexes]
            self.mean_std = self.mean_std[indexes]

    def reset_batch_pointer(self):
        '''
        Reset the data pointer
        '''
        self.pointer = 0

# %%
import tensorflow as tf
import numpy as np
from tensorflow.python.ops import rnn_cell


# The Vanilla LSTM model
class Model():

    def __init__(self, args, infer=False):
        '''
        Initialisation function for the class Model.
        Params:
        args: Contains arguments required for the Model creation
        '''

        # If sampling new trajectories, then infer mode
        if infer:
            # Infer one position at a time
            args.batch_size = 1
            args.seq_length = 1

        # Store the arguments
        self.args = args

        # Initialize a BasicLSTMCell recurrent unit
        # args.rnn_size contains the dimension of the hidden state of the LSTM
        cell = rnn_cell.BasicLSTMCell(args.rnn_size, state_is_tuple=False)

        # Multi-layer RNN construction, if more than one layer
        cell = rnn_cell.MultiRNNCell([cell] * args.num_layers, state_is_tuple=False)

        # TODO: (improve) Dropout layer can be added here
        # Store the recurrent unit
        self.cell = cell

        # TODO: (resolve) Do we need to use a fixed seq_length?
        # Input data contains sequence of (x,y) points
        self.input_data = tf.placeholder(tf.float32, [None, args.seq_length, 2])
        # target data contains sequences of (x,y) points as well
        self.target_data = tf.placeholder(tf.float32, [None, args.seq_length, 2])

        # Learning rate
        self.lr = tf.Variable(args.learning_rate, trainable=False, name="learning_rate")

        # Initial cell state of the LSTM (initialised with zeros)
        self.initial_state = cell.zero_state(batch_size=args.batch_size, dtype=tf.float32)

        # Output size is the set of parameters (mu, sigma, corr)
        output_size = 5  # 2 mu, 2 sigma and 1 corr

        # Embedding for the spatial coordinates
        with tf.variable_scope("coordinate_embedding"):
            #  The spatial embedding using a ReLU layer
            #  Embed the 2D coordinates into embedding_size dimensions
            #  TODO: (improve) For now assume embedding_size = rnn_size
            embedding_w = tf.get_variable("embedding_w", [2, args.embedding_size])
            embedding_b = tf.get_variable("embedding_b", [args.embedding_size])

        # Output linear layer
        with tf.variable_scope("rnnlm"):
            output_w = tf.get_variable("output_w", [args.rnn_size, output_size], initializer=tf.truncated_normal_initializer(stddev=0.01), trainable=True)
            output_b = tf.get_variable("output_b", [output_size], initializer=tf.constant_initializer(0.01), trainable=True)

        # Split inputs according to sequences.
        inputs = tf.split(self.input_data, args.seq_length, 1)
        # Get a list of 2D tensors. Each of size numPoints x 2
        inputs = [tf.squeeze(input_, [1]) for input_ in inputs]

        # Embed the input spatial points into the embedding space
        embedded_inputs = []
        for x in inputs:
            # Each x is a 2D tensor of size numPoints x 2
            # Embedding layer
            embedded_x = tf.nn.relu(tf.add(tf.matmul(x, embedding_w), embedding_b))
            embedded_inputs.append(embedded_x)

        # Feed the embedded input data, the initial state of the LSTM cell, the recurrent unit to the seq2seq decoder
        outputs, last_state = tf.contrib.legacy_seq2seq.rnn_decoder(embedded_inputs, self.initial_state, self.cell, loop_function=None)

        # Concatenate the outputs from the RNN decoder and reshape it to ?xargs.rnn_size
        output = tf.reshape(tf.concat( outputs,1), [-1, args.rnn_size])

        # Apply the output linear layer
        output = tf.nn.xw_plus_b(output, output_w, output_b)
        
        # Store the final LSTM cell state after the input data has been feeded
        self.final_state = last_state

        # reshape target data so that it aligns with predictions
        flat_target_data = tf.reshape(self.target_data, [-1, 2])
        # Extract the x-coordinates and y-coordinates from the target data
        [x_data, y_data] = tf.split(flat_target_data, 2, 1)

        def tf_2d_normal(x, y, mux, muy, sx, sy, rho):
            '''
            Function that implements the PDF of a 2D normal distribution
            params:
            x : input x points
            y : input y points
            mux : mean of the distribution in x
            muy : mean of the distribution in y
            sx : std dev of the distribution in x
            sy : std dev of the distribution in y
            rho : Correlation factor of the distribution
            '''
            # eq 3 in the paper
            # and eq 24 & 25 in Graves (2013)
            # Calculate (x - mux) and (y-muy)
            
            normx = tf.subtract(x, mux)
            normy = tf.subtract(y, muy)
            # Calculate sx*sy
            sxsy = tf.multiply(sx, sy)
            # Calculate the exponential factor
            z = tf.square(tf.div(normx, sx)) + tf.square(tf.div(normy, sy)) - 2*tf.div(tf.multiply(rho, tf.multiply(normx, normy)), sxsy)
            negRho = 1 - tf.square(rho)
            # Numerator
            result = tf.exp(tf.div(-z, 2*negRho))
            # Normalization constant
            denom = 2 * np.pi * tf.multiply(sxsy, tf.sqrt(negRho))
            # Final PDF calculation
            result = tf.div(result, denom)
            self.result = result
            return result

        # Important difference between loss func of Social LSTM and Graves (2013)
        # is that it is evaluated over all time steps in the latter whereas it is
        # done from t_obs+1 to t_pred in the former
        def get_lossfunc(z_mux, z_muy, z_sx, z_sy, z_corr, x_data, y_data):
            '''
            Function to calculate given a 2D distribution over x and y, and target data
            of observed x and y points
            params:
            z_mux : mean of the distribution in x
            z_muy : mean of the distribution in y
            z_sx : std dev of the distribution in x
            z_sy : std dev of the distribution in y
            z_rho : Correlation factor of the distribution
            x_data : target x points
            y_data : target y points
            '''
            step = tf.constant(1e-3, dtype=tf.float32, shape=(1, 1))

            # Calculate the PDF of the data w.r.t to the distribution
            result0_1 = tf_2d_normal(x_data, y_data, z_mux, z_muy, z_sx, z_sy, z_corr)
            result0_2 = tf_2d_normal(tf.add(x_data, step), y_data, z_mux, z_muy, z_sx, z_sy, z_corr)
            result0_3 = tf_2d_normal(x_data, tf.add(y_data, step), z_mux, z_muy, z_sx, z_sy, z_corr)
            result0_4 = tf_2d_normal(tf.add(x_data, step), tf.add(y_data, step), z_mux, z_muy, z_sx, z_sy, z_corr)

            result0 = tf.div(tf.add(tf.add(tf.add(result0_1, result0_2), result0_3), result0_4), tf.constant(4.0, dtype=tf.float32, shape=(1, 1)))
            result0 = tf.multiply(tf.multiply(result0, step), step)

            # For numerical stability purposes
            epsilon = 1e-20

            # TODO: (resolve) I don't think we need this as we don't have the inner
            # summation
            # result1 = tf.reduce_sum(result0, 1, keep_dims=True)
            # Apply the log operation
            result1 = -tf.log(tf.maximum(result0, epsilon))  # Numerical stability

            # TODO: For now, implementing loss func over all time-steps
            # Sum up all log probabilities for each data point
            return tf.reduce_sum(result1)

        def get_coef(output):
            # eq 20 -> 22 of Graves (2013)
            # TODO : (resolve) Does Social LSTM paper do this as well?
            # the paper says otherwise but this is essential as we cannot
            # have negative standard deviation and correlation needs to be between
            # -1 and 1

            z = output
            # Split the output into 5 parts corresponding to means, std devs and corr
            z_mux, z_muy, z_sx, z_sy, z_corr = tf.split(z, 5, 1)

            # The output must be exponentiated for the std devs
            z_sx = tf.exp(z_sx)
            z_sy = tf.exp(z_sy)
            # Tanh applied to keep it in the range [-1, 1]
            z_corr = tf.tanh(z_corr)

            return [z_mux, z_muy, z_sx, z_sy, z_corr]
        
        # Extract the coef from the output of the linear layer
        [o_mux, o_muy, o_sx, o_sy, o_corr] = get_coef(output)
        # Store the output from the model
        self.output = output

        # Store the predicted outputs
        self.mux = o_mux
        self.muy = o_muy
        self.sx = o_sx
        self.sy = o_sy
        self.corr = o_corr

        # Compute the loss function
        lossfunc = get_lossfunc(o_mux, o_muy, o_sx, o_sy, o_corr, x_data, y_data)

        # Compute the cost
        self.cost = tf.div(lossfunc, (args.batch_size * args.seq_length))

        # Get trainable_variables
        tvars = tf.trainable_variables()

        # TODO: (resolve) We are clipping the gradients as is usually done in LSTM
        # implementations. Social LSTM paper doesn't mention about this at all
        # Calculate gradients of the cost w.r.t all the trainable variables
        self.gradients = tf.gradients(self.cost, tvars)
        # Clip the gradients if they are larger than the value given in args
        grads, _ = tf.clip_by_global_norm(self.gradients, args.grad_clip)

        # NOTE: Using RMSprop as suggested by Social LSTM instead of Adam as Graves(2013) does
        # optimizer = tf.train.AdamOptimizer(self.lr)
        # initialize the optimizer with teh given learning rate
        optimizer = tf.train.RMSPropOptimizer(self.lr)

        # Train operator
        self.train_op = optimizer.apply_gradients(zip(grads, tvars))

    def sample(self, sess, traj, num=10):
        '''
        Given an initial trajectory (as a list of tuples of points), predict the future trajectory
        until a few timesteps
        Params:
        sess: Current session of Tensorflow
        traj: List of past trajectory points
        num: Number of time-steps into the future to be predicted
        '''
        def sample_gaussian_2d(mux, muy, sx, sy, rho):
            '''
            Function to sample a point from a given 2D normal distribution
            params:
            mux : mean of the distribution in x
            muy : mean of the distribution in y
            sx : std dev of the distribution in x
            sy : std dev of the distribution in y
            rho : Correlation factor of the distribution
            '''
            # Extract mean
            mean = [mux, muy]
            # Extract covariance matrix
            cov = [[sx*sx, rho*sx*sy], [rho*sx*sy, sy*sy]]
            # Sample a point from the multivariate normal distribution
            x = np.random.multivariate_normal(mean, cov, 1)
            return x[0][0], x[0][1]

        # Initial state with zeros
        state = sess.run(self.cell.zero_state(1, tf.float32))

        # Iterate over all the positions seen in the trajectory
        for pos in traj[:-1]:
            # Create the input data tensor
            data = np.zeros((1, 1, 2), dtype=np.float32)
            data[0, 0, 0] = pos[0]  # x
            data[0, 0, 1] = pos[1]  # y

            # Create the feed dict
            feed = {self.input_data: data, self.initial_state: state}
            # Get the final state after processing the current position
            [state] = sess.run([self.final_state], feed)

        ret = traj

        # Last position in the observed trajectory
        last_pos = traj[-1]

        # Construct the input data tensor for the last point
        prev_data = np.zeros((1, 1, 2), dtype=np.float32)
        prev_data[0, 0, 0] = last_pos[0]  # x
        prev_data[0, 0, 1] = last_pos[1]  # y

        for t in range(num):
            # Create the feed dict
            feed = {self.input_data: prev_data, self.initial_state: state}

            # Get the final state and also the coef of the distribution of the next point
            [o_mux, o_muy, o_sx, o_sy, o_corr, state] = sess.run([self.mux, self.muy, self.sx, self.sy, self.corr, self.final_state], feed)

            # Sample the next point from the distribution
            next_x, next_y = sample_gaussian_2d(o_mux[0][0], o_muy[0][0], o_sx[0][0], o_sy[0][0], o_corr[0][0])
            # Append the new point to the trajectory
            ret = np.vstack((ret, [next_x, next_y]))

            # Set the current sampled position as the last observed position
            prev_data[0, 0, 0] = next_x
            prev_data[0, 0, 1] = next_y

        return ret

# %%
import numpy as np
import tensorflow as tf
import argparse
import os
import time
import pickle

#things to do : 

#exlude samples with low std (<1) from training (say they are not moving and won´t start moving...)
#adjust hyper param
#Integrate map info

class arguments():
   def __init__(self, rnn_size = 128, num_layers = 1, model = 'lstm', batch_size = 50, seq_length = 7,
         num_epochs = 200, save_every = 500,  grad_clip = 10, learning_rate = 0.003,
         decay_rate = 0.98, keep_prob = 0.75, embedding_size = 128, leaveDataset = 1):
    self.rnn_size = rnn_size
    self.num_layers = num_layers
    self.model = model
    self.batch_size = batch_size
    self.seq_length = seq_length
    self.num_epochs = num_epochs
    self.save_every = save_every
    self.grad_clip = grad_clip
    self.learning_rate = learning_rate
    self.decay_rate = decay_rate
    self.keep_prob = keep_prob
    self.embedding_size = embedding_size
    self.leaveDataset = leaveDataset

def main():
  args = arguments()
  tf.reset_default_graph()#SAMPLE
  train(args)


def train(args):
    datasets = list(range(90)) #we train with first 90 scenes

    # Create the data loader object. This object would preprocess the data in terms of
    # batches each of size args.batch_size, of length args.seq_length
    data_loader = DataLoader(args.batch_size, args.seq_length, datasets, force_preprocessing=True, testing = False)

    # Save the arguments int the config file
    with open(os.path.join('/content/gdrive/My Drive/vanillaData', 'config.pkl'), 'wb') as f:
        pickle.dump(args, f)

    # Create a Vanilla LSTM model with the arguments
    model = Model(args)

    # Initialize a TensorFlow session
    with tf.Session() as sess:
        # Initialize all the variables in the graph
        sess.run(tf.initialize_all_variables())
        # Add all the variables to the list of variables to be saved
        saver = tf.train.Saver(tf.all_variables())

        # For each epoch
        print(args.num_epochs)
        for e in range(args.num_epochs):
            # Assign the learning rate (decayed acc. to the epoch number)
            sess.run(tf.assign(model.lr, args.learning_rate * (args.decay_rate ** e)))
            # Reset the pointers in the data loader object
            data_loader.reset_batch_pointer()
            # Get the initial cell state of the LSTM
            state = sess.run(model.initial_state)

            # For each batch in this epoch
            losst = 0
            for b in range(data_loader.num_batches):
                # Tic
                start = time.time()
                # Get the source and target data of the current batch
                # x has the source data, y has the target data
                x, y, _ = data_loader.next_batch()

                # Feed the source, target data and the initial LSTM state to the model
                feed = {model.input_data: x, model.target_data: y, model.initial_state: state}
                # Fetch the loss of the model on this batch, the final LSTM state from the session
                train_loss, state, _ , pred= sess.run([model.cost, model.final_state, model.train_op, model.output], feed)
                                # Toc
                losst += train_loss
                end = time.time()
                if(b==50):
                  print(
                    "{}/{} (epoch {}), train_loss = {:.3f}, time/batch = {:.3f}"
                    .format(
                        e * data_loader.num_batches + b,
                        args.num_epochs * data_loader.num_batches,
                        e,
                        losst/b, end - start))
                  losst=0

                # Save the model if the current epoch and batch number match the frequency
                if (e * data_loader.num_batches + b) % args.save_every == 0 and ((e * data_loader.num_batches + b) > 0):
                    checkpoint_path = os.path.join('save', 'model.ckpt')
                    saver.save(sess, checkpoint_path, global_step=e * data_loader.num_batches + b)
                    print("model saved to {}".format(checkpoint_path))

main()
# Out:
# Creating pre-processed data from raw data
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7f88751cce80>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# 200
# 50/21400 (epoch 0), train_loss = 19.244, time/batch = 0.013
# 157/21400 (epoch 1), train_loss = 16.714, time/batch = 0.012
# 264/21400 (epoch 2), train_loss = 15.522, time/batch = 0.012
# 371/21400 (epoch 3), train_loss = 15.103, time/batch = 0.012
# 478/21400 (epoch 4), train_loss = 14.896, time/batch = 0.013
# model saved to save/model.ckpt
# 585/21400 (epoch 5), train_loss = 14.772, time/batch = 0.012
# 692/21400 (epoch 6), train_loss = 14.678, time/batch = 0.013
# 799/21400 (epoch 7), train_loss = 14.559, time/batch = 0.013
# 906/21400 (epoch 8), train_loss = 14.491, time/batch = 0.013
# model saved to save/model.ckpt
# 1013/21400 (epoch 9), train_loss = 14.423, time/batch = 0.012
# 1120/21400 (epoch 10), train_loss = 14.363, time/batch = 0.012
# 1227/21400 (epoch 11), train_loss = 14.295, time/batch = 0.013
# 1334/21400 (epoch 12), train_loss = 14.234, time/batch = 0.012
# 1441/21400 (epoch 13), train_loss = 14.188, time/batch = 0.012
# model saved to save/model.ckpt
# 1548/21400 (epoch 14), train_loss = 14.138, time/batch = 0.013
# 1655/21400 (epoch 15), train_loss = 14.113, time/batch = 0.012
# 1762/21400 (epoch 16), train_loss = 14.061, time/batch = 0.013
# 1869/21400 (epoch 17), train_loss = 14.026, time/batch = 0.012
# 1976/21400 (epoch 18), train_loss = 14.000, time/batch = 0.013
# model saved to save/model.ckpt
# 2083/21400 (epoch 19), train_loss = 13.942, time/batch = 0.013
# 2190/21400 (epoch 20), train_loss = 13.909, time/batch = 0.013
# 2297/21400 (epoch 21), train_loss = 13.854, time/batch = 0.013
# 2404/21400 (epoch 22), train_loss = 13.854, time/batch = 0.016
# model saved to save/model.ckpt
# 2511/21400 (epoch 23), train_loss = 13.795, time/batch = 0.012
# 2618/21400 (epoch 24), train_loss = 13.770, time/batch = 0.014
# 2725/21400 (epoch 25), train_loss = 13.728, time/batch = 0.012
# 2832/21400 (epoch 26), train_loss = 13.710, time/batch = 0.012
# 2939/21400 (epoch 27), train_loss = 13.672, time/batch = 0.012
# model saved to save/model.ckpt
# 3046/21400 (epoch 28), train_loss = 13.639, time/batch = 0.012
# 3153/21400 (epoch 29), train_loss = 13.608, time/batch = 0.012
# 3260/21400 (epoch 30), train_loss = 13.597, time/batch = 0.012
# 3367/21400 (epoch 31), train_loss = 13.558, time/batch = 0.012
# 3474/21400 (epoch 32), train_loss = 13.535, time/batch = 0.012
# model saved to save/model.ckpt
# 3581/21400 (epoch 33), train_loss = 13.529, time/batch = 0.012
# 3688/21400 (epoch 34), train_loss = 13.500, time/batch = 0.012
# 3795/21400 (epoch 35), train_loss = 13.461, time/batch = 0.012
# 3902/21400 (epoch 36), train_loss = 13.447, time/batch = 0.012
# model saved to save/model.ckpt
# 4009/21400 (epoch 37), train_loss = 13.412, time/batch = 0.015
# 4116/21400 (epoch 38), train_loss = 13.393, time/batch = 0.013
# 4223/21400 (epoch 39), train_loss = 13.366, time/batch = 0.012
# 4330/21400 (epoch 40), train_loss = 13.355, time/batch = 0.012
# 4437/21400 (epoch 41), train_loss = 13.332, time/batch = 0.013
# model saved to save/model.ckpt
# 4544/21400 (epoch 42), train_loss = 13.310, time/batch = 0.016
# 4651/21400 (epoch 43), train_loss = 13.281, time/batch = 0.012
# 4758/21400 (epoch 44), train_loss = 13.263, time/batch = 0.012
# 4865/21400 (epoch 45), train_loss = 13.264, time/batch = 0.012
# 4972/21400 (epoch 46), train_loss = 13.236, time/batch = 0.012
# model saved to save/model.ckpt
# 5079/21400 (epoch 47), train_loss = 13.221, time/batch = 0.017
# 5186/21400 (epoch 48), train_loss = 13.191, time/batch = 0.013
# 5293/21400 (epoch 49), train_loss = 13.176, time/batch = 0.012
# 5400/21400 (epoch 50), train_loss = 13.158, time/batch = 0.013
# model saved to save/model.ckpt
# 5507/21400 (epoch 51), train_loss = 13.154, time/batch = 0.012
# 5614/21400 (epoch 52), train_loss = 13.131, time/batch = 0.015
# 5721/21400 (epoch 53), train_loss = 13.120, time/batch = 0.013
# 5828/21400 (epoch 54), train_loss = 13.105, time/batch = 0.012
# 5935/21400 (epoch 55), train_loss = 13.081, time/batch = 0.013
# model saved to save/model.ckpt
# 6042/21400 (epoch 56), train_loss = 13.073, time/batch = 0.012
# 6149/21400 (epoch 57), train_loss = 13.055, time/batch = 0.012
# 6256/21400 (epoch 58), train_loss = 13.045, time/batch = 0.012
# 6363/21400 (epoch 59), train_loss = 13.028, time/batch = 0.013
# 6470/21400 (epoch 60), train_loss = 13.021, time/batch = 0.013
# model saved to save/model.ckpt
# 6577/21400 (epoch 61), train_loss = 13.003, time/batch = 0.013
# 6684/21400 (epoch 62), train_loss = 12.986, time/batch = 0.013
# 6791/21400 (epoch 63), train_loss = 12.983, time/batch = 0.013
# 6898/21400 (epoch 64), train_loss = 12.957, time/batch = 0.012
# model saved to save/model.ckpt
# 7005/21400 (epoch 65), train_loss = 12.966, time/batch = 0.012
# 7112/21400 (epoch 66), train_loss = 12.945, time/batch = 0.012
# 7219/21400 (epoch 67), train_loss = 12.927, time/batch = 0.012
# 7326/21400 (epoch 68), train_loss = 12.920, time/batch = 0.012
# 7433/21400 (epoch 69), train_loss = 12.908, time/batch = 0.012
# model saved to save/model.ckpt
# 7540/21400 (epoch 70), train_loss = 12.890, time/batch = 0.012
# 7647/21400 (epoch 71), train_loss = 12.883, time/batch = 0.012
# 7754/21400 (epoch 72), train_loss = 12.887, time/batch = 0.013
# 7861/21400 (epoch 73), train_loss = 12.867, time/batch = 0.012
# 7968/21400 (epoch 74), train_loss = 12.851, time/batch = 0.012
# model saved to save/model.ckpt
# 8075/21400 (epoch 75), train_loss = 12.846, time/batch = 0.013
# 8182/21400 (epoch 76), train_loss = 12.840, time/batch = 0.013
# 8289/21400 (epoch 77), train_loss = 12.829, time/batch = 0.013
# 8396/21400 (epoch 78), train_loss = 12.824, time/batch = 0.016
# model saved to save/model.ckpt
# 8503/21400 (epoch 79), train_loss = 12.814, time/batch = 0.012
# 8610/21400 (epoch 80), train_loss = 12.789, time/batch = 0.012
# 8717/21400 (epoch 81), train_loss = 12.793, time/batch = 0.013
# 8824/21400 (epoch 82), train_loss = 12.772, time/batch = 0.012
# 8931/21400 (epoch 83), train_loss = 12.776, time/batch = 0.012
# model saved to save/model.ckpt
# 9038/21400 (epoch 84), train_loss = 12.763, time/batch = 0.013
# 9145/21400 (epoch 85), train_loss = 12.754, time/batch = 0.013
# 9252/21400 (epoch 86), train_loss = 12.750, time/batch = 0.012
# 9359/21400 (epoch 87), train_loss = 12.739, time/batch = 0.013
# 9466/21400 (epoch 88), train_loss = 12.737, time/batch = 0.012
# model saved to save/model.ckpt
# 9573/21400 (epoch 89), train_loss = 12.721, time/batch = 0.012
# 9680/21400 (epoch 90), train_loss = 12.714, time/batch = 0.012
# 9787/21400 (epoch 91), train_loss = 12.709, time/batch = 0.012
# 9894/21400 (epoch 92), train_loss = 12.701, time/batch = 0.013
# model saved to save/model.ckpt
# 10001/21400 (epoch 93), train_loss = 12.692, time/batch = 0.014
# 10108/21400 (epoch 94), train_loss = 12.681, time/batch = 0.012
# 10215/21400 (epoch 95), train_loss = 12.678, time/batch = 0.013
# 10322/21400 (epoch 96), train_loss = 12.672, time/batch = 0.012
# 10429/21400 (epoch 97), train_loss = 12.661, time/batch = 0.012
# model saved to save/model.ckpt
# 10536/21400 (epoch 98), train_loss = 12.662, time/batch = 0.012
# 10643/21400 (epoch 99), train_loss = 12.654, time/batch = 0.012
# 10750/21400 (epoch 100), train_loss = 12.642, time/batch = 0.012
# 10857/21400 (epoch 101), train_loss = 12.639, time/batch = 0.013
# 10964/21400 (epoch 102), train_loss = 12.627, time/batch = 0.012
# model saved to save/model.ckpt
# 11071/21400 (epoch 103), train_loss = 12.624, time/batch = 0.012
# 11178/21400 (epoch 104), train_loss = 12.618, time/batch = 0.012
# 11285/21400 (epoch 105), train_loss = 12.622, time/batch = 0.013
# 11392/21400 (epoch 106), train_loss = 12.614, time/batch = 0.016
# 11499/21400 (epoch 107), train_loss = 12.603, time/batch = 0.012
# model saved to save/model.ckpt
# 11606/21400 (epoch 108), train_loss = 12.599, time/batch = 0.012
# 11713/21400 (epoch 109), train_loss = 12.593, time/batch = 0.012
# 11820/21400 (epoch 110), train_loss = 12.586, time/batch = 0.012
# 11927/21400 (epoch 111), train_loss = 12.589, time/batch = 0.013
# model saved to save/model.ckpt
# 12034/21400 (epoch 112), train_loss = 12.582, time/batch = 0.019
# 12141/21400 (epoch 113), train_loss = 12.575, time/batch = 0.012
# 12248/21400 (epoch 114), train_loss = 12.566, time/batch = 0.012
# 12355/21400 (epoch 115), train_loss = 12.568, time/batch = 0.013
# 12462/21400 (epoch 116), train_loss = 12.558, time/batch = 0.013
# model saved to save/model.ckpt
# 12569/21400 (epoch 117), train_loss = 12.555, time/batch = 0.013
# 12676/21400 (epoch 118), train_loss = 12.551, time/batch = 0.013
# 12783/21400 (epoch 119), train_loss = 12.547, time/batch = 0.012
# 12890/21400 (epoch 120), train_loss = 12.545, time/batch = 0.013
# 12997/21400 (epoch 121), train_loss = 12.527, time/batch = 0.012
# model saved to save/model.ckpt
# 13104/21400 (epoch 122), train_loss = 12.535, time/batch = 0.012
# 13211/21400 (epoch 123), train_loss = 12.528, time/batch = 0.012
# 13318/21400 (epoch 124), train_loss = 12.525, time/batch = 0.013
# 13425/21400 (epoch 125), train_loss = 12.519, time/batch = 0.013
# model saved to save/model.ckpt
# 13532/21400 (epoch 126), train_loss = 12.517, time/batch = 0.012
# 13639/21400 (epoch 127), train_loss = 12.513, time/batch = 0.013
# 13746/21400 (epoch 128), train_loss = 12.504, time/batch = 0.012
# 13853/21400 (epoch 129), train_loss = 12.509, time/batch = 0.012
# 13960/21400 (epoch 130), train_loss = 12.498, time/batch = 0.013
# model saved to save/model.ckpt
# 14067/21400 (epoch 131), train_loss = 12.493, time/batch = 0.012
# 14174/21400 (epoch 132), train_loss = 12.488, time/batch = 0.012
# 14281/21400 (epoch 133), train_loss = 12.490, time/batch = 0.013
# 14388/21400 (epoch 134), train_loss = 12.487, time/batch = 0.013
# 14495/21400 (epoch 135), train_loss = 12.482, time/batch = 0.013
# model saved to save/model.ckpt
# 14602/21400 (epoch 136), train_loss = 12.477, time/batch = 0.013
# 14709/21400 (epoch 137), train_loss = 12.472, time/batch = 0.013
# 14816/21400 (epoch 138), train_loss = 12.468, time/batch = 0.012
# 14923/21400 (epoch 139), train_loss = 12.466, time/batch = 0.013
# model saved to save/model.ckpt
# 15030/21400 (epoch 140), train_loss = 12.464, time/batch = 0.012
# 15137/21400 (epoch 141), train_loss = 12.455, time/batch = 0.012
# 15244/21400 (epoch 142), train_loss = 12.454, time/batch = 0.012
# 15351/21400 (epoch 143), train_loss = 12.452, time/batch = 0.013
# 15458/21400 (epoch 144), train_loss = 12.447, time/batch = 0.012
# model saved to save/model.ckpt
# 15565/21400 (epoch 145), train_loss = 12.445, time/batch = 0.012
# 15672/21400 (epoch 146), train_loss = 12.440, time/batch = 0.012
# 15779/21400 (epoch 147), train_loss = 12.436, time/batch = 0.013
# 15886/21400 (epoch 148), train_loss = 12.432, time/batch = 0.012
# 15993/21400 (epoch 149), train_loss = 12.433, time/batch = 0.013
# model saved to save/model.ckpt
# 16100/21400 (epoch 150), train_loss = 12.428, time/batch = 0.012
# 16207/21400 (epoch 151), train_loss = 12.426, time/batch = 0.012
# 16314/21400 (epoch 152), train_loss = 12.422, time/batch = 0.018
# 16421/21400 (epoch 153), train_loss = 12.419, time/batch = 0.012
# model saved to save/model.ckpt
# 16528/21400 (epoch 154), train_loss = 12.416, time/batch = 0.012
# 16635/21400 (epoch 155), train_loss = 12.414, time/batch = 0.013
# 16742/21400 (epoch 156), train_loss = 12.408, time/batch = 0.012
# 16849/21400 (epoch 157), train_loss = 12.407, time/batch = 0.012
# 16956/21400 (epoch 158), train_loss = 12.406, time/batch = 0.013
# model saved to save/model.ckpt
# 17063/21400 (epoch 159), train_loss = 12.405, time/batch = 0.017
# 17170/21400 (epoch 160), train_loss = 12.402, time/batch = 0.013
# 17277/21400 (epoch 161), train_loss = 12.400, time/batch = 0.012
# 17384/21400 (epoch 162), train_loss = 12.393, time/batch = 0.012
# 17491/21400 (epoch 163), train_loss = 12.397, time/batch = 0.012
# model saved to save/model.ckpt
# 17598/21400 (epoch 164), train_loss = 12.392, time/batch = 0.013
# 17705/21400 (epoch 165), train_loss = 12.388, time/batch = 0.012
# 17812/21400 (epoch 166), train_loss = 12.385, time/batch = 0.013
# 17919/21400 (epoch 167), train_loss = 12.386, time/batch = 0.012
# model saved to save/model.ckpt
# 18026/21400 (epoch 168), train_loss = 12.381, time/batch = 0.012
# 18133/21400 (epoch 169), train_loss = 12.381, time/batch = 0.012
# 18240/21400 (epoch 170), train_loss = 12.379, time/batch = 0.012
# 18347/21400 (epoch 171), train_loss = 12.376, time/batch = 0.012
# 18454/21400 (epoch 172), train_loss = 12.373, time/batch = 0.013
# model saved to save/model.ckpt
# 18561/21400 (epoch 173), train_loss = 12.371, time/batch = 0.013
# 18668/21400 (epoch 174), train_loss = 12.371, time/batch = 0.012
# 18775/21400 (epoch 175), train_loss = 12.366, time/batch = 0.013
# 18882/21400 (epoch 176), train_loss = 12.365, time/batch = 0.012
# 18989/21400 (epoch 177), train_loss = 12.362, time/batch = 0.012
# model saved to save/model.ckpt
# 19096/21400 (epoch 178), train_loss = 12.361, time/batch = 0.012
# 19203/21400 (epoch 179), train_loss = 12.357, time/batch = 0.012
# 19310/21400 (epoch 180), train_loss = 12.358, time/batch = 0.012
# 19417/21400 (epoch 181), train_loss = 12.354, time/batch = 0.017
# model saved to save/model.ckpt
# 19524/21400 (epoch 182), train_loss = 12.353, time/batch = 0.013
# 19631/21400 (epoch 183), train_loss = 12.352, time/batch = 0.016
# 19738/21400 (epoch 184), train_loss = 12.351, time/batch = 0.012
# 19845/21400 (epoch 185), train_loss = 12.349, time/batch = 0.012
# 19952/21400 (epoch 186), train_loss = 12.348, time/batch = 0.013
# model saved to save/model.ckpt
# 20059/21400 (epoch 187), train_loss = 12.346, time/batch = 0.012
# 20166/21400 (epoch 188), train_loss = 12.343, time/batch = 0.012
# 20273/21400 (epoch 189), train_loss = 12.342, time/batch = 0.012
# 20380/21400 (epoch 190), train_loss = 12.340, time/batch = 0.013
# 20487/21400 (epoch 191), train_loss = 12.339, time/batch = 0.013
# model saved to save/model.ckpt
# 20594/21400 (epoch 192), train_loss = 12.338, time/batch = 0.013
# 20701/21400 (epoch 193), train_loss = 12.337, time/batch = 0.012
# 20808/21400 (epoch 194), train_loss = 12.336, time/batch = 0.012
# 20915/21400 (epoch 195), train_loss = 12.337, time/batch = 0.014
# model saved to save/model.ckpt
# 21022/21400 (epoch 196), train_loss = 12.334, time/batch = 0.012
# 21129/21400 (epoch 197), train_loss = 12.333, time/batch = 0.013
# 21236/21400 (epoch 198), train_loss = 12.331, time/batch = 0.012
# 21343/21400 (epoch 199), train_loss = 12.330, time/batch = 0.012

# %% [markdown]
# # Get test MSE using LSTM and a linnear predictor

# %%
def get_mean_error(predicted_traj, true_traj, observed_length):
    '''
    Function that computes the mean euclidean distance error between the
    predicted and the true trajectory
    params:
    predicted_traj : numpy matrix with the points of the predicted trajectory
    true_traj : numpy matrix with the points of the true trajectory
    observed_length : The length of trajectory observed
    '''
    # The data structure to store all errors
    error = np.zeros(len(true_traj) - observed_length)
    # For each point in the predicted part of the trajectory
    for i in range(observed_length, len(true_traj)):
        # The predicted position
        pred_pos = predicted_traj[i, :]
        # The true position
        true_pos = true_traj[i, :]

        # The euclidean distance is the error
        error[i-observed_length] = np.linalg.norm(true_pos - pred_pos)

    # Return the mean error
    return np.mean(error)

class ParserArgs():
  def __init__(self):
    self.obs_length = 4
    self.pred_length = 3
    self.test_dataset = list(range(90,100))
    

# Read the arguments
sample_args = ParserArgs()

#test scenes
testScenes = list(range(90,100))

# Load the saved arguments to the model from the config file
with open(os.path.join('/content/gdrive/My Drive/vanillaData', 'config.pkl'), 'rb') as f:
    saved_args = pickle.load(f)

#with trainer.model.graph.as_default():
# Initialize TensorFlow session
tf.reset_default_graph()#SAMPLE

# Initialize with the saved args
model = Model(saved_args, True)

sess = tf.InteractiveSession()
# Initialize TensorFlow saver
saver = tf.train.Saver()

# Get the checkpoint state to load the model from
ckpt = tf.train.get_checkpoint_state('save')

print('loading model: ', ckpt.model_checkpoint_path)
# Restore the model at the checpoint
saver.restore(sess, ckpt.model_checkpoint_path)

# Initialize the dataloader object to
# Get sequences of length obs_length+pred_length
data_loader = DataLoader(1, sample_args.pred_length + sample_args.obs_length, testScenes, force_preprocessing= True, testing = True)

mean_std = data_loader.mean_std
# Reset the data pointers of the data loader object
data_loader.reset_batch_pointer()

# Maintain the total_error until now
total_error = 0.
counter = 0.
j = 0
for b in range(data_loader.num_batches):
    # Get the source, target data for the next batch
    x, y, mean_std = data_loader.next_batch()
    mean_x = mean_std[0][0]
    std_x = mean_std[0][1]
    mean_y = mean_std[1][0]
    std_y = mean_std[1][1]
    traj_real = x[0]
    # The observed part of the trajectory
    obs_traj = x[0][:sample_args.obs_length]
    
    # Get the complete trajectory with both the observed and the predicted part from the model
    complete_traj = model.sample(sess, obs_traj, num=sample_args.pred_length)
    j+=1
    obs_traj = np.array(obs_traj)
    print(obs_traj.shape)
    complete_traj[:,0] = complete_traj[:,0] *(std_x +0.5)+mean_x
    complete_traj[:,1] = complete_traj[:,1] *(std_y +0.5)+mean_y
    
    traj_real[:,0] = traj_real[:,0] *(std_x +0.5)+mean_x
    traj_real[:,1] = traj_real[:,1] *(std_y +0.5)+mean_y
    

    # Compute the mean error between the predicted part and the true trajectory
    error = get_mean_error(complete_traj, traj_real, sample_args.obs_length)
    total_error += error
    print("Processed trajectory number : ", b, "out of ", data_loader.num_batches, " trajectories")
    index = mean_std[2]
    if(j<50):
      print(complete_traj)
      print(map_data_split[90+index[0], index[1]][index[2]])
      print(error)

# Print the mean error across all the batches
print("Total mean error of the model is ", total_error/data_loader.num_batches)
# Out:
# WARNING:tensorflow:<tensorflow.python.ops.rnn_cell_impl.BasicLSTMCell object at 0x7f888358b128>: Using a concatenated state is slower and will soon be deprecated.  Use state_is_tuple=True.
# loading model:  save/model.ckpt-21000
# INFO:tensorflow:Restoring parameters from save/model.ckpt-21000
# Creating pre-processed data from raw data
# (4, 2)
# Processed trajectory number :  0 out of  586  trajectories
# [[ 3159.04370528 10474.6001755 ]
#  [ 3178.63540151 10429.59645951]
#  [ 3197.65260414 10385.365235  ]
#  [ 3216.88948048 10341.43685603]
#  [ 3236.30774157 10298.99910473]
#  [ 3256.34818307 10252.16988024]
#  [ 3274.87817244 10208.52937915]]
# [[ 3159.04370528 10474.6001755 ]
#  [ 3178.63540151 10429.59645951]
#  [ 3197.65260414 10385.365235  ]
#  [ 3216.88948048 10341.43685603]
#  [ 3235.86855835 10298.28985586]
#  [ 3254.10794472 10256.27910802]
#  [ 3272.8876781  10214.07059312]
#  [ 3291.54139771 10172.55610703]
#  [ 3305.94341512 10139.88822281]
#  [ 3323.01729004 10099.92607869]]
# 3.8007702290760648
# (4, 2)
# Processed trajectory number :  1 out of  586  trajectories
# [[ 3392.9        10089.47      ]
#  [ 3378.61       10119.87      ]
#  [ 3363.23       10152.57      ]
#  [ 3351.31       10182.29      ]
#  [ 3340.79078489 10213.58934519]
#  [ 3333.66983794 10242.7953881 ]
#  [ 3327.86977433 10271.46918331]]
# [[ 3392.9  10089.47]
#  [ 3378.61 10119.87]
#  [ 3363.23 10152.57]
#  [ 3351.31 10182.29]
#  [ 3339.25 10211.94]
#  [ 3329.84 10240.88]
#  [ 3321.51 10270.51]
#  [ 3319.6  10300.47]
#  [ 3324.81 10322.14]
#  [ 3330.69 10349.06]]
# 4.32362232406522
# (4, 2)
# Processed trajectory number :  2 out of  586  trajectories
# [[3519.89       9774.66      ]
#  [3502.52       9811.56      ]
#  [3494.76       9830.69      ]
#  [3485.06       9852.91      ]
#  [3479.82690102 9869.73868833]
#  [3475.07367169 9883.10698001]
#  [3470.8857432  9897.52591209]]
# [[ 3519.89  9774.66]
#  [ 3502.52  9811.56]
#  [ 3494.76  9830.69]
#  [ 3485.06  9852.91]
#  [ 3474.02  9875.72]
#  [ 3458.63  9906.97]
#  [ 3447.99  9931.51]
#  [ 3437.15  9955.68]
#  [ 3423.59  9985.7 ]
#  [ 3408.09 10023.1 ]]
# 26.097875319835225
# (4, 2)
# Processed trajectory number :  3 out of  586  trajectories
# [[ 3374.02       10211.74      ]
#  [ 3377.36       10205.56      ]
#  [ 3380.42       10199.22      ]
#  [ 3383.17       10192.75      ]
#  [ 3385.72702549 10186.95719422]
#  [ 3388.88766366 10179.89511904]
#  [ 3392.45601652 10172.45662371]]
# [[ 3374.02 10211.74]
#  [ 3377.36 10205.56]
#  [ 3380.42 10199.22]
#  [ 3383.17 10192.75]
#  [ 3389.55 10172.77]
#  [ 3391.68 10166.11]
#  [ 3393.28 10160.44]
#  [ 3398.43 10145.09]
#  [ 3399.31 10138.09]
#  [ 3400.08 10123.65]]
# 13.601059259672965
# (4, 2)
# Processed trajectory number :  4 out of  586  trajectories
# [[ 3471.23        9901.52      ]
#  [ 3459.31        9930.01      ]
#  [ 3448.03        9958.76      ]
#  [ 3437.56        9987.84      ]
#  [ 3428.4261897  10017.49072186]
#  [ 3420.09957225 10047.11887772]
#  [ 3413.24897371 10075.62160989]]
# [[ 3471.23  9901.52]
#  [ 3459.31  9930.01]
#  [ 3448.03  9958.76]
#  [ 3437.56  9987.84]
#  [ 3425.8  10016.39]
#  [ 3412.79 10044.81]
#  [ 3401.45 10072.79]
#  [ 3388.63 10101.66]
#  [ 3380.8  10122.83]
#  [ 3369.52 10151.58]]
# 7.549028743000484
# (4, 2)
# Processed trajectory number :  5 out of  586  trajectories
# [[ 3162.07       10195.53      ]
#  [ 3164.68       10199.46      ]
#  [ 3167.3        10203.4       ]
#  [ 3167.8        10207.31      ]
#  [ 3167.15102667 10211.54978041]
#  [ 3166.12331927 10215.48994692]
#  [ 3163.71565748 10219.53675406]]
# [[ 3162.07 10195.53]
#  [ 3164.68 10199.46]
#  [ 3167.3  10203.4 ]
#  [ 3167.8  10207.31]
#  [ 3168.65 10212.04]
#  [ 3169.63 10216.84]
#  [ 3171.61 10220.22]
#  [ 3174.11 10224.6 ]
#  [ 3176.32 10228.46]
#  [ 3176.51 10232.27]]
# 4.419512636092233
# (4, 2)
# Processed trajectory number :  6 out of  586  trajectories
# [[ 3126.56       10349.29      ]
#  [ 3129.21       10342.69      ]
#  [ 3132.15       10335.51      ]
#  [ 3134.68       10329.02      ]
#  [ 3137.07153916 10323.45531468]
#  [ 3140.13632411 10316.24142666]
#  [ 3143.11773193 10309.37036723]]
# [[ 3126.56 10349.29]
#  [ 3129.21 10342.69]
#  [ 3132.15 10335.51]
#  [ 3134.68 10329.02]
#  [ 3137.13 10323.03]
#  [ 3139.3  10318.01]
#  [ 3144.33 10306.64]
#  [ 3146.56 10302.92]
#  [ 3152.27 10288.57]
#  [ 3162.48 10265.33]]
# 1.7910165687566701
# (4, 2)
# Processed trajectory number :  7 out of  586  trajectories
# [[ 3061.6        10678.23      ]
#  [ 3081.34       10631.92      ]
#  [ 3100.66       10586.74      ]
#  [ 3119.77       10539.85      ]
#  [ 3136.26805135 10497.65395713]
#  [ 3152.65849244 10453.51142625]
#  [ 3168.68234125 10410.12042659]]
# [[ 3061.6  10678.23]
#  [ 3081.34 10631.92]
#  [ 3100.66 10586.74]
#  [ 3119.77 10539.85]
#  [ 3140.92 10492.56]
#  [ 3160.46 10448.38]
#  [ 3179.17 10403.89]
#  [ 3199.07 10357.92]
#  [ 3215.96 10321.92]
#  [ 3236.44 10275.91]]
# 9.478348972557898
# (4, 2)
# Processed trajectory number :  8 out of  586  trajectories
# [[ 3344.88       10386.68      ]
#  [ 3360.14       10407.22      ]
#  [ 3376.07       10427.21      ]
#  [ 3395.6        10443.49      ]
#  [ 3418.72036244 10457.80475424]
#  [ 3451.67965971 10474.15643097]
#  [ 3479.21041302 10484.70666974]]
# [[ 3344.88 10386.68]
#  [ 3360.14 10407.22]
#  [ 3376.07 10427.21]
#  [ 3395.6  10443.49]
#  [ 3417.21 10457.02]
#  [ 3439.56 10471.  ]
#  [ 3486.36 10494.23]
#  [ 3509.69 10503.94]
#  [ 3536.97 10515.38]
#  [ 3570.56 10529.61]]
# 8.711476892094895
# (4, 2)
# Processed trajectory number :  9 out of  586  trajectories
# [[ 3242.64       10081.09      ]
#  [ 3238.46       10090.89      ]
#  [ 3234.28       10100.7       ]
#  [ 3230.11       10110.5       ]
#  [ 3225.66958456 10121.09607201]
#  [ 3221.40835711 10131.60704929]
#  [ 3216.95501666 10143.69938086]]
# [[ 3242.64 10081.09]
#  [ 3238.46 10090.89]
#  [ 3234.28 10100.7 ]
#  [ 3230.11 10110.5 ]
#  [ 3228.47 10115.59]
#  [ 3225.94 10120.28]
#  [ 3223.41 10124.98]
#  [ 3220.88 10129.67]
#  [ 3218.14 10134.47]
#  [ 3215.08 10139.07]]
# 12.726094083396347
# (4, 2)
# Processed trajectory number :  10 out of  586  trajectories
# [[ 3235.86855835 10298.28985586]
#  [ 3254.10794472 10256.27910802]
#  [ 3272.8876781  10214.07059312]
#  [ 3291.54139771 10172.55610703]
#  [ 3308.75948126 10136.19959852]
#  [ 3328.92065062 10090.24541823]
#  [ 3348.31943896 10045.39284242]]
# [[ 3235.86855835 10298.28985586]
#  [ 3254.10794472 10256.27910802]
#  [ 3272.8876781  10214.07059312]
#  [ 3291.54139771 10172.55610703]
#  [ 3305.94341512 10139.88822281]
#  [ 3323.01729004 10099.92607869]
#  [ 3342.88433187 10053.33113372]
#  [ 3358.71310878 10016.05748956]
#  [ 3373.56491673  9980.81212704]
#  [ 3388.36097983  9946.09233832]]
# 8.533333485063322
# (4, 2)
# Processed trajectory number :  11 out of  586  trajectories
# [[ 3339.25       10211.94      ]
#  [ 3329.84       10240.88      ]
#  [ 3321.51       10270.51      ]
#  [ 3319.6        10300.47      ]
#  [ 3317.48280727 10333.60862801]
#  [ 3314.74553299 10372.5280901 ]
#  [ 3313.51567699 10415.68364493]]
# [[ 3339.25 10211.94]
#  [ 3329.84 10240.88]
#  [ 3321.51 10270.51]
#  [ 3319.6  10300.47]
#  [ 3324.81 10322.14]
#  [ 3330.69 10349.06]
#  [ 3346.13 10380.42]
#  [ 3390.15 10434.4 ]
#  [ 3389.15 10428.53]
#  [ 3418.83 10448.42]]
# 30.00503003125475
# (4, 2)
# Processed trajectory number :  12 out of  586  trajectories
# [[ 3474.02        9875.72      ]
#  [ 3458.63        9906.97      ]
#  [ 3447.99        9931.51      ]
#  [ 3437.15        9955.68      ]
#  [ 3429.671784    9975.82095254]
#  [ 3425.74574777  9990.92952051]
#  [ 3423.22667876 10003.92760889]]
# [[ 3474.02  9875.72]
#  [ 3458.63  9906.97]
#  [ 3447.99  9931.51]
#  [ 3437.15  9955.68]
#  [ 3423.59  9985.7 ]
#  [ 3408.09 10023.1 ]
#  [ 3394.45 10055.04]
#  [ 3379.59 10089.97]
#  [ 3365.98 10121.86]
#  [ 3351.75 10154.4 ]]
# 35.65145389031824
# (4, 2)
# Processed trajectory number :  13 out of  586  trajectories
# [[ 3389.55       10172.77      ]
#  [ 3391.68       10166.11      ]
#  [ 3393.28       10160.44      ]
#  [ 3398.43       10145.09      ]
#  [ 3403.71251382 10132.94823485]
#  [ 3409.78802711 10120.50121679]
#  [ 3416.42760881 10106.53707225]]
# [[ 3389.55 10172.77]
#  [ 3391.68 10166.11]
#  [ 3393.28 10160.44]
#  [ 3398.43 10145.09]
#  [ 3399.31 10138.09]
#  [ 3400.08 10123.65]
#  [ 3400.01 10108.29]
#  [ 3399.68 10099.94]
#  [ 3397.11 10092.62]
#  [ 3393.91 10087.62]]
# 11.161958043464816
# (4, 2)
# Processed trajectory number :  14 out of  586  trajectories
# [[ 3425.8        10016.39      ]
#  [ 3412.79       10044.81      ]
#  [ 3401.45       10072.79      ]
#  [ 3388.63       10101.66      ]
#  [ 3376.58033382 10130.36708303]
#  [ 3365.62457625 10158.03694776]
#  [ 3354.43650183 10188.26977795]]
# [[ 3425.8  10016.39]
#  [ 3412.79 10044.81]
#  [ 3401.45 10072.79]
#  [ 3388.63 10101.66]
#  [ 3380.8  10122.83]
#  [ 3369.52 10151.58]
#  [ 3357.01 10182.45]
#  [ 3348.02 10207.59]
#  [ 3339.82 10231.52]
#  [ 3333.59 10257.18]]
# 7.514089866890906
# (4, 2)
# Processed trajectory number :  15 out of  586  trajectories
# [[ 3168.65       10212.04      ]
#  [ 3169.63       10216.84      ]
#  [ 3171.61       10220.22      ]
#  [ 3174.11       10224.6       ]
#  [ 3177.59260424 10228.71742984]
#  [ 3181.33523375 10231.81593902]
#  [ 3184.96710063 10233.8871257 ]]
# [[ 3168.65 10212.04]
#  [ 3169.63 10216.84]
#  [ 3171.61 10220.22]
#  [ 3174.11 10224.6 ]
#  [ 3176.32 10228.46]
#  [ 3176.51 10232.27]
#  [ 3176.32 10237.08]
#  [ 3172.9  10242.22]
#  [ 3175.23 10249.2 ]
#  [ 3171.72 10258.94]]
# 5.120891486525875
# (4, 2)
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:245: RuntimeWarning: covariance is not positive-semidefinite.
# Processed trajectory number :  16 out of  586  trajectories
# [[ 3140.92       10492.56      ]
#  [ 3160.46       10448.38      ]
#  [ 3179.17       10403.89      ]
#  [ 3199.07       10357.92      ]
#  [ 3219.73326503 10311.69879109]
#  [ 3241.83625785 10261.38490742]
#  [ 3261.94090005 10213.09240025]]
# [[ 3140.92 10492.56]
#  [ 3160.46 10448.38]
#  [ 3179.17 10403.89]
#  [ 3199.07 10357.92]
#  [ 3215.96 10321.92]
#  [ 3236.44 10275.91]
#  [ 3260.01 10221.68]
#  [ 3279.24 10178.76]
#  [ 3297.18 10137.07]
#  [ 3315.69 10094.08]]
# 11.730845589432988
# (4, 2)
# Processed trajectory number :  17 out of  586  trajectories
# [[ 3485.74       10092.26      ]
#  [ 3485.74       10092.26      ]
#  [ 3485.74       10092.26      ]
#  [ 3485.74       10092.26      ]
#  [ 3485.73994634 10092.25971926]
#  [ 3485.74034904 10092.26043376]
#  [ 3485.74154871 10092.26174548]]
# [[ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]]
# 0.0010586904188963665
# (4, 2)
# Processed trajectory number :  18 out of  586  trajectories
# [[3513.51       9764.01      ]
#  [3506.06       9780.95      ]
#  [3487.41       9821.64      ]
#  [3476.74       9844.93      ]
#  [3467.01518491 9868.0862487 ]
#  [3458.8415992  9890.06200934]
#  [3453.79297884 9907.45377054]]
# [[ 3513.51  9764.01]
#  [ 3506.06  9780.95]
#  [ 3487.41  9821.64]
#  [ 3476.74  9844.93]
#  [ 3461.85  9876.89]
#  [ 3448.85  9906.01]
#  [ 3436.98  9937.28]
#  [ 3422.54  9973.28]
#  [ 3407.72 10005.06]
#  [ 3395.12 10041.46]]
# 21.08836963023927
# (4, 2)
# Processed trajectory number :  19 out of  586  trajectories
# [[ 3305.94341512 10139.88822281]
#  [ 3323.01729004 10099.92607869]
#  [ 3342.88433187 10053.33113372]
#  [ 3358.71310878 10016.05748956]
#  [ 3371.4539381   9984.3126122 ]
#  [ 3384.39369606  9950.39928991]
#  [ 3396.57451763  9919.00623388]]
# [[ 3305.94341512 10139.88822281]
#  [ 3323.01729004 10099.92607869]
#  [ 3342.88433187 10053.33113372]
#  [ 3358.71310878 10016.05748956]
#  [ 3373.56491673  9980.81212704]
#  [ 3388.36097983  9946.09233832]
#  [ 3402.38401753  9913.26874065]
#  [ 3416.083395    9881.79601267]
#  [ 3429.36438137  9851.36409846]
#  [ 3442.2874727   9822.17089634]]
# 6.0361842369845355
# (4, 2)
# Processed trajectory number :  20 out of  586  trajectories
# [[ 3423.59        9985.7       ]
#  [ 3408.09       10023.1       ]
#  [ 3394.45       10055.04      ]
#  [ 3379.59       10089.97      ]
#  [ 3365.84193645 10123.1486549 ]
#  [ 3353.23786669 10153.72710693]
#  [ 3343.19884412 10180.47599952]]
# [[ 3423.59  9985.7 ]
#  [ 3408.09 10023.1 ]
#  [ 3394.45 10055.04]
#  [ 3379.59 10089.97]
#  [ 3365.98 10121.86]
#  [ 3351.75 10154.4 ]
#  [ 3336.69 10187.27]
#  [ 3321.26 10221.75]
#  [ 3306.   10256.66]
#  [ 3289.42 10294.52]]
# 4.1125580769857
# (4, 2)
# Processed trajectory number :  21 out of  586  trajectories
# [[ 3399.31       10138.09      ]
#  [ 3400.08       10123.65      ]
#  [ 3400.01       10108.29      ]
#  [ 3399.68       10099.94      ]
#  [ 3398.82216916 10090.85385078]
#  [ 3398.44445097 10081.28912121]
#  [ 3398.46718927 10070.43913957]]
# [[ 3399.31 10138.09]
#  [ 3400.08 10123.65]
#  [ 3400.01 10108.29]
#  [ 3399.68 10099.94]
#  [ 3397.11 10092.62]
#  [ 3393.91 10087.62]
#  [ 3390.42 10082.67]
#  [ 3384.17 10072.25]
#  [ 3380.36 10067.88]
#  [ 3374.23 10062.27]]
# 8.29594234187617
# (4, 2)
# Processed trajectory number :  22 out of  586  trajectories
# [[ 3380.8        10122.83      ]
#  [ 3369.52       10151.58      ]
#  [ 3357.01       10182.45      ]
#  [ 3348.02       10207.59      ]
#  [ 3341.3064267  10230.71077405]
#  [ 3336.15423512 10253.10720236]
#  [ 3333.7781828  10275.54211351]]
# [[ 3380.8  10122.83]
#  [ 3369.52 10151.58]
#  [ 3357.01 10182.45]
#  [ 3348.02 10207.59]
#  [ 3339.82 10231.52]
#  [ 3333.59 10257.18]
#  [ 3330.02 10279.85]
#  [ 3330.86 10304.33]
#  [ 3333.43 10328.6 ]
#  [ 3340.03 10353.1 ]]
# 4.074007683491616
# (4, 2)
# Processed trajectory number :  23 out of  586  trajectories
# [[ 3215.96       10321.92      ]
#  [ 3236.44       10275.91      ]
#  [ 3260.01       10221.68      ]
#  [ 3279.24       10178.76      ]
#  [ 3296.30616553 10142.84234225]
#  [ 3316.00365785 10102.80754348]
#  [ 3335.04847363 10064.22934323]]
# [[ 3215.96 10321.92]
#  [ 3236.44 10275.91]
#  [ 3260.01 10221.68]
#  [ 3279.24 10178.76]
#  [ 3297.18 10137.07]
#  [ 3315.69 10094.08]
#  [ 3332.26 10055.44]
#  [ 3348.6  10016.69]
#  [ 3363.7   9980.93]
#  [ 3378.68  9943.35]]
# 7.9307859174617805
# (4, 2)
# Processed trajectory number :  24 out of  586  trajectories
# [[ 3485.74       10092.26      ]
#  [ 3485.74       10092.26      ]
#  [ 3485.74       10092.26      ]
#  [ 3485.74       10092.26      ]
#  [ 3485.74106232 10092.26101763]
#  [ 3485.7436731  10092.26294767]
#  [ 3485.74393204 10092.26486177]]
# [[ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]]
# 0.0041445032119366496
# (4, 2)
# Processed trajectory number :  25 out of  586  trajectories
# [[ 3461.85        9876.89      ]
#  [ 3448.85        9906.01      ]
#  [ 3436.98        9937.28      ]
#  [ 3422.54        9973.28      ]
#  [ 3409.48643202 10008.72851   ]
#  [ 3397.01143642 10044.99652162]
#  [ 3384.76664433 10077.13353737]]
# [[ 3461.85  9876.89]
#  [ 3448.85  9906.01]
#  [ 3436.98  9937.28]
#  [ 3422.54  9973.28]
#  [ 3407.72 10005.06]
#  [ 3395.12 10041.46]
#  [ 3381.   10076.58]
#  [ 3367.05 10110.41]
#  [ 3353.4  10144.35]
#  [ 3338.87 10177.95]]
# 3.963096830025382
# (4, 2)
# Processed trajectory number :  26 out of  586  trajectories
# [[3364.08       9861.9       ]
#  [3363.06       9861.73      ]
#  [3363.07       9861.69      ]
#  [3363.21       9861.09      ]
#  [3363.41977624 9860.16242019]
#  [3363.3147479  9859.57226025]
#  [3363.75810109 9858.38491208]]
# [[3364.08 9861.9 ]
#  [3363.06 9861.73]
#  [3363.07 9861.69]
#  [3363.21 9861.09]
#  [3363.11 9861.42]
#  [3363.11 9861.46]
#  [3363.31 9860.59]
#  [3363.22 9861.01]
#  [3363.1  9861.5 ]
#  [3363.09 9861.56]]
# 1.8147130951392143
# (4, 2)
# Processed trajectory number :  27 out of  586  trajectories
# [[3515.47       9813.34      ]
#  [3511.14       9814.21      ]
#  [3500.8        9816.2       ]
#  [3495.71       9817.5       ]
#  [3489.74209571 9817.12921238]
#  [3485.94094493 9817.30740614]
#  [3484.16741182 9815.87044936]]
# [[3515.47 9813.34]
#  [3511.14 9814.21]
#  [3500.8  9816.2 ]
#  [3495.71 9817.5 ]
#  [3490.96 9819.65]
#  [3486.21 9821.8 ]
#  [3481.46 9823.95]
#  [3478.55 9825.39]
#  [3473.3  9828.97]
#  [3468.75 9832.06]]
# 5.273776615790423
# (4, 2)
# Processed trajectory number :  28 out of  586  trajectories
# [[3373.56491673 9980.81212704]
#  [3388.36097983 9946.09233832]
#  [3402.38401753 9913.26874065]
#  [3416.083395   9881.79601267]
#  [3429.56412754 9853.423756  ]
#  [3444.89059978 9820.30478853]
#  [3458.25783708 9792.25915126]]
# [[3373.56491673 9980.81212704]
#  [3388.36097983 9946.09233832]
#  [3402.38401753 9913.26874065]
#  [3416.083395   9881.79601267]
#  [3429.36438137 9851.36409846]
#  [3442.2874727  9822.17089634]
#  [3454.44208712 9794.84086331]
#  [3467.18582013 9766.34537485]
#  [3479.9981328  9737.62589757]
#  [3493.65714308 9706.92727561]]
# 3.29310330526827
# (4, 2)
# Processed trajectory number :  29 out of  586  trajectories
# [[ 3339.82       10231.52      ]
#  [ 3333.59       10257.18      ]
#  [ 3330.02       10279.85      ]
#  [ 3330.86       10304.33      ]
#  [ 3334.25813394 10310.22022031]
#  [ 3337.12726212 10310.62340711]
#  [ 3338.78315197 10309.02450947]]
# [[ 3339.82 10231.52]
#  [ 3333.59 10257.18]
#  [ 3330.02 10279.85]
#  [ 3330.86 10304.33]
#  [ 3333.43 10328.6 ]
#  [ 3340.03 10353.1 ]
#  [ 3351.35 10378.76]
#  [ 3364.69 10403.09]
#  [ 3384.42 10426.84]
#  [ 3400.91 10442.68]]
# 43.944283315102574
# (4, 2)
# Processed trajectory number :  30 out of  586  trajectories
# [[ 3297.18       10137.07      ]
#  [ 3315.69       10094.08      ]
#  [ 3332.26       10055.44      ]
#  [ 3348.6        10016.69      ]
#  [ 3364.77318795  9981.98419881]
#  [ 3383.10341008  9943.02005883]
#  [ 3401.50501538  9904.90013493]]
# [[ 3297.18 10137.07]
#  [ 3315.69 10094.08]
#  [ 3332.26 10055.44]
#  [ 3348.6  10016.69]
#  [ 3363.7   9980.93]
#  [ 3378.68  9943.35]
#  [ 3391.91  9908.21]
#  [ 3404.98  9870.64]
#  [ 3416.83  9839.15]
#  [ 3430.61  9803.28]]
# 5.36330040129155
# (4, 2)
# Processed trajectory number :  31 out of  586  trajectories
# [[ 3485.74       10092.26      ]
#  [ 3485.74       10092.26      ]
#  [ 3485.74       10092.26      ]
#  [ 3485.74       10092.26      ]
#  [ 3485.74162466 10092.26112351]
#  [ 3485.74303783 10092.26171675]
#  [ 3485.74297246 10092.26428877]]
# [[ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]
#  [ 3485.74 10092.26]]
# 0.0035609356209034032
# (4, 2)
# Processed trajectory number :  32 out of  586  trajectories
# [[3490.96       9819.65      ]
#  [3486.21       9821.8       ]
#  [3481.46       9823.95      ]
#  [3478.55       9825.39      ]
#  [3476.48082757 9827.17698948]
#  [3474.87390268 9829.35677676]
#  [3473.42883031 9830.20472631]]
# [[3490.96 9819.65]
#  [3486.21 9821.8 ]
#  [3481.46 9823.95]
#  [3478.55 9825.39]
#  [3473.3  9828.97]
#  [3468.75 9832.06]
#  [3463.54 9835.53]
#  [3457.1  9839.11]
#  [3450.18 9841.3 ]
#  [3441.95 9842.96]]
# 7.1923048288487905
# (4, 2)
# Processed trajectory number :  33 out of  586  trajectories
# [[3489.55       9795.2       ]
#  [3483.61       9797.86      ]
#  [3480.82       9799.67      ]
#  [3478.11       9802.09      ]
#  [3476.84811474 9804.41540604]
#  [3475.32062769 9805.10159798]
#  [3474.86188564 9805.67536114]]
# [[3489.55 9795.2 ]
#  [3483.61 9797.86]
#  [3480.82 9799.67]
#  [3478.11 9802.09]
#  [3474.6  9804.34]
#  [3471.2  9807.38]
#  [3469.4  9810.16]
#  [3464.41 9813.48]
#  [3459.41 9816.81]
#  [3453.61 9820.27]]
# 4.6750249101636285
# (4, 2)
# Processed trajectory number :  34 out of  586  trajectories
# [[3429.36438137 9851.36409846]
#  [3442.2874727  9822.17089634]
#  [3454.44208712 9794.84086331]
#  [3467.18582013 9766.34537485]
#  [3479.26173519 9740.12776521]
#  [3491.87314286 9712.92927659]
#  [3502.40889257 9690.07934064]]
# [[3429.36438137 9851.36409846]
#  [3442.2874727  9822.17089634]
#  [3454.44208712 9794.84086331]
#  [3467.18582013 9766.34537485]
#  [3479.9981328  9737.62589757]
#  [3493.65714308 9706.92727561]
#  [3507.93290591 9674.58877324]
#  [3526.99867645 9630.94515267]
#  [3541.91054415 9596.70530773]
#  [3556.94786257 9562.07867244]]
# 8.4385201735389
# (4, 2)
# Processed trajectory number :  35 out of  586  trajectories
# [[3363.7        9980.93      ]
#  [3378.68       9943.35      ]
#  [3391.91       9908.21      ]
#  [3404.98       9870.64      ]
#  [3414.0130784  9840.35535604]
#  [3423.60001682 9805.90976646]
#  [3430.12487761 9773.95111513]]
# [[3363.7  9980.93]
#  [3378.68 9943.35]
#  [3391.91 9908.21]
#  [3404.98 9870.64]
#  [3416.83 9839.15]
#  [3430.61 9803.28]
#  [3443.63 9766.81]
#  [3462.73 9719.24]
#  [3478.05 9681.42]
#  [3494.16 9641.06]]
# 8.60930115315108
# (4, 2)
# Processed trajectory number :  36 out of  586  trajectories
# [[3473.3        9828.97      ]
#  [3468.75       9832.06      ]
#  [3463.54       9835.53      ]
#  [3457.1        9839.11      ]
#  [3450.98944514 9842.4601345 ]
#  [3444.20191719 9845.90512522]
#  [3437.63871724 9849.12715382]]
# [[3473.3  9828.97]
#  [3468.75 9832.06]
#  [3463.54 9835.53]
#  [3457.1  9839.11]
#  [3450.18 9841.3 ]
#  [3441.95 9842.96]
#  [3434.95 9844.32]
#  [3427.96 9845.69]
#  [3420.96 9847.05]
#  [3413.96 9848.41]]
# 3.5433351639411
# (4, 2)
# Processed trajectory number :  37 out of  586  trajectories
# [[3477.76       8935.05      ]
#  [3478.57       8935.43      ]
#  [3480.2        8936.18      ]
#  [3480.6        8936.37      ]
#  [3480.7539535  8936.86287526]
#  [3481.42709023 8936.62376983]
#  [3481.31258508 8936.78072427]]
# [[3477.76 8935.05]
#  [3478.57 8935.43]
#  [3480.2  8936.18]
#  [3480.6  8936.37]
#  [3481.01 8936.56]
#  [3481.41 8936.75]
#  [3481.82 8936.94]
#  [3482.22 8937.13]
#  [3482.63 8937.32]
#  [3483.03 8937.51]]
# 0.3519365748545269
# (4, 2)
# Processed trajectory number :  38 out of  586  trajectories
# [[3827.73       9279.31      ]
#  [3827.33       9278.6       ]
#  [3827.44       9278.51      ]
#  [3827.54       9278.43      ]
#  [3827.53572228 9278.12801092]
#  [3827.65720665 9279.18534354]
#  [3827.3490926  9279.5070129 ]]
# [[3827.73 9279.31]
#  [3827.33 9278.6 ]
#  [3827.44 9278.51]
#  [3827.54 9278.43]
#  [3827.7  9278.62]
#  [3827.85 9278.82]
#  [3828.   9279.01]
#  [3828.16 9279.2 ]
#  [3828.31 9279.39]
#  [3828.47 9279.59]]
# 0.5835824758563549
# (4, 2)
# Processed trajectory number :  39 out of  586  trajectories
# [[3619.04       9040.74      ]
#  [3619.53       9040.83      ]
#  [3619.61       9040.84      ]
#  [3619.69       9040.86      ]
#  [3619.9889385  9040.8305708 ]
#  [3620.20923254 9040.94141428]
#  [3620.31595781 9041.4520547 ]]
# [[3619.04 9040.74]
#  [3619.53 9040.83]
#  [3619.61 9040.84]
#  [3619.69 9040.86]
#  [3619.78 9040.87]
#  [3619.86 9040.88]
#  [3619.94 9040.9 ]
#  [3620.02 9040.91]
#  [3620.1  9040.93]
#  [3620.18 9040.94]]
# 0.4117104740279219
# (4, 2)
# Processed trajectory number :  40 out of  586  trajectories
# [[3479.9981328  9737.62589757]
#  [3493.65714308 9706.92727561]
#  [3507.93290591 9674.58877324]
#  [3526.99867645 9630.94515267]
#  [3543.16391267 9593.86628902]
#  [3561.07602432 9553.18732238]
#  [3577.74515128 9515.31776721]]
# [[3479.9981328  9737.62589757]
#  [3493.65714308 9706.92727561]
#  [3507.93290591 9674.58877324]
#  [3526.99867645 9630.94515267]
#  [3541.91054415 9596.70530773]
#  [3556.94786257 9562.07867244]
#  [3571.70489621 9527.89920592]
#  [3584.92246287 9496.78127616]
#  [3598.80179903 9463.94133577]
#  [3613.34337823 9429.66534807]]
# 8.954197255920201
# (4, 2)
# Processed trajectory number :  41 out of  586  trajectories
# [[3416.83       9839.15      ]
#  [3430.61       9803.28      ]
#  [3443.63       9766.81      ]
#  [3462.73       9719.24      ]
#  [3479.80572685 9677.65287464]
#  [3499.02732291 9632.91148363]
#  [3516.45258096 9591.8662972 ]]
# [[3416.83 9839.15]
#  [3430.61 9803.28]
#  [3443.63 9766.81]
#  [3462.73 9719.24]
#  [3478.05 9681.42]
#  [3494.16 9641.06]
#  [3509.87 9599.71]
#  [3523.88 9562.55]
#  [3541.24 9520.  ]
#  [3556.69 9473.54]]
# 7.96251143792747
# (4, 2)
# Processed trajectory number :  42 out of  586  trajectories
# [[3450.18       9841.3       ]
#  [3441.95       9842.96      ]
#  [3434.95       9844.32      ]
#  [3427.96       9845.69      ]
#  [3420.6254449  9845.95455004]
#  [3416.48688563 9846.69994946]
#  [3414.27422932 9847.87178615]]
# [[3450.18 9841.3 ]
#  [3441.95 9842.96]
#  [3434.95 9844.32]
#  [3427.96 9845.69]
#  [3420.96 9847.05]
#  [3413.96 9848.41]
#  [3406.23 9850.86]
#  [3399.12 9854.71]
#  [3391.86 9858.25]
#  [3387.28 9859.68]]
# 4.259284339396312
# (4, 2)
# Processed trajectory number :  43 out of  586  trajectories
# [[3481.01       8936.56      ]
#  [3481.41       8936.75      ]
#  [3481.82       8936.94      ]
#  [3482.22       8937.13      ]
#  [3481.866823   8937.30164571]
#  [3481.56700039 8937.42189252]
#  [3481.28693912 8937.55756247]]
# [[3481.01 8936.56]
#  [3481.41 8936.75]
#  [3481.82 8936.94]
#  [3482.22 8937.13]
#  [3482.63 8937.32]
#  [3483.03 8937.51]
#  [3483.44 8937.69]
#  [3483.84 8937.88]
#  [3484.25 8938.07]
#  [3484.66 8938.26]]
# 1.462059403808083
# (4, 2)
# Processed trajectory number :  44 out of  586  trajectories
# [[3827.7        9278.62      ]
#  [3827.85       9278.82      ]
#  [3828.         9279.01      ]
#  [3828.16       9279.2       ]
#  [3828.04693778 9279.09965817]
#  [3828.06552806 9278.99528335]
#  [3828.15052071 9278.85116545]]
# [[3827.7  9278.62]
#  [3827.85 9278.82]
#  [3828.   9279.01]
#  [3828.16 9279.2 ]
#  [3828.31 9279.39]
#  [3828.47 9279.59]
#  [3828.62 9279.78]
#  [3828.78 9279.97]
#  [3828.93 9280.16]
#  [3829.09 9280.36]]
# 0.7172529108617219
# (4, 2)
# Processed trajectory number :  45 out of  586  trajectories
# [[3619.78       9040.87      ]
#  [3619.86       9040.88      ]
#  [3619.94       9040.9       ]
#  [3620.02       9040.91      ]
#  [3620.13334988 9040.99972652]
#  [3620.01087867 9041.11028977]
#  [3620.1084707  9041.15011539]]
# [[3619.78 9040.87]
#  [3619.86 9040.88]
#  [3619.94 9040.9 ]
#  [3620.02 9040.91]
#  [3620.1  9040.93]
#  [3620.18 9040.94]
#  [3620.26 9040.95]
#  [3620.35 9040.97]
#  [3620.43 9040.98]
#  [3620.51 9041.  ]]
# 0.1894351768181888
# (4, 2)
# Processed trajectory number :  46 out of  586  trajectories
# [[3733.43       8954.49      ]
#  [3733.43       8954.49      ]
#  [3733.61       8954.37      ]
#  [3733.78       8954.25      ]
#  [3733.91797084 8954.25539145]
#  [3734.17154091 8953.98866389]
#  [3733.69744984 8954.09387963]]
# [[3733.43 8954.49]
#  [3733.43 8954.49]
#  [3733.61 8954.37]
#  [3733.78 8954.25]
#  [3733.94 8954.12]
#  [3734.1  8953.97]
#  [3734.25 8953.82]
#  [3734.4  8953.67]
#  [3734.53 8953.51]
#  [3734.66 8953.34]]
# 0.27593652970275867
# (4, 2)
# Processed trajectory number :  47 out of  586  trajectories
# [[3459.76       9817.79      ]
#  [3454.17       9820.96      ]
#  [3447.9        9822.52      ]
#  [3439.14       9823.79      ]
#  [3431.27313583 9823.8157091 ]
#  [3423.95663069 9824.29036746]
#  [3416.12663761 9825.72128154]]
# [[3459.76 9817.79]
#  [3454.17 9820.96]
#  [3447.9  9822.52]
#  [3439.14 9823.79]
#  [3430.38 9825.06]
#  [3424.04 9824.54]
#  [3417.79 9825.69]
#  [3411.51 9826.67]
#  [3405.81 9828.39]
#  [3398.8  9832.33]]
# 1.152830791662694
# (4, 2)
# Processed trajectory number :  48 out of  586  trajectories
# [[3835.41       9283.1       ]
#  [3835.43       9283.1       ]
#  [3835.44       9283.1       ]
#  [3835.45       9283.1       ]
#  [3835.45235873 9283.09954454]
#  [3835.43690141 9283.10340667]
#  [3835.44233568 9283.10814298]]
# [[3835.41 9283.1 ]
#  [3835.43 9283.1 ]
#  [3835.44 9283.1 ]
#  [3835.45 9283.1 ]
#  [3835.46 9283.1 ]
#  [3835.48 9283.1 ]
#  [3835.47 9283.18]
#  [3835.46 9283.27]
#  [3835.45 9283.35]
#  [3835.44 9283.43]]
# 0.042628732303783334
# (4, 2)
# Processed trajectory number :  49 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  50 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  51 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  52 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  53 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  54 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  55 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  56 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  57 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  58 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  59 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  60 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  61 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  62 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  63 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  64 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  65 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  66 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  67 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  68 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  69 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  70 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  71 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  72 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  73 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  74 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  75 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  76 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  77 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  78 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  79 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  80 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  81 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  82 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  83 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  84 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  85 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  86 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  87 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  88 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  89 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  90 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  91 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  92 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  93 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  94 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  95 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  96 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  97 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  98 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  99 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  100 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  101 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  102 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  103 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  104 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  105 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  106 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  107 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  108 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  109 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  110 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  111 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  112 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  113 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  114 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  115 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  116 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  117 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  118 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  119 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  120 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  121 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  122 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  123 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  124 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  125 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  126 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  127 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  128 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  129 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  130 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  131 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  132 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  133 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  134 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  135 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  136 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  137 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  138 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  139 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  140 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  141 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  142 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  143 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  144 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  145 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  146 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  147 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  148 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  149 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  150 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  151 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  152 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  153 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  154 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  155 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  156 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  157 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  158 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  159 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  160 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  161 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  162 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  163 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  164 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  165 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  166 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  167 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  168 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  169 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  170 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  171 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  172 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  173 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  174 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  175 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  176 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  177 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  178 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  179 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  180 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  181 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  182 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  183 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  184 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  185 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  186 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  187 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  188 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  189 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  190 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  191 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  192 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  193 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  194 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  195 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  196 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  197 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  198 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  199 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  200 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  201 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  202 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  203 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  204 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  205 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  206 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  207 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  208 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  209 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  210 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  211 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  212 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  213 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  214 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  215 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  216 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  217 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  218 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  219 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  220 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  221 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  222 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  223 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  224 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  225 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  226 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  227 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  228 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  229 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  230 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  231 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  232 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  233 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  234 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  235 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  236 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  237 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  238 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  239 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  240 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  241 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  242 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  243 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  244 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  245 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  246 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  247 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  248 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  249 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  250 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  251 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  252 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  253 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  254 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  255 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  256 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  257 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  258 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  259 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  260 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  261 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  262 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  263 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  264 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  265 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  266 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  267 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  268 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  269 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  270 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  271 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  272 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  273 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  274 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  275 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  276 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  277 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  278 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  279 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  280 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  281 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  282 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  283 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  284 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  285 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  286 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  287 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  288 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  289 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  290 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  291 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  292 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  293 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  294 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  295 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  296 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  297 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  298 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  299 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  300 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  301 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  302 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  303 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  304 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  305 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  306 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  307 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  308 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  309 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  310 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  311 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  312 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  313 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  314 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  315 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  316 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  317 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  318 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  319 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  320 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  321 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  322 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  323 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  324 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  325 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  326 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  327 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  328 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  329 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  330 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  331 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  332 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  333 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  334 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  335 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  336 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  337 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  338 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  339 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  340 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  341 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  342 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  343 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  344 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  345 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  346 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  347 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  348 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  349 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  350 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  351 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  352 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  353 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  354 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  355 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  356 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  357 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  358 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  359 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  360 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  361 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  362 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  363 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  364 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  365 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  366 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  367 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  368 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  369 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  370 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  371 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  372 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  373 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  374 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  375 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  376 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  377 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  378 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  379 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  380 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  381 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  382 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  383 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  384 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  385 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  386 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  387 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  388 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  389 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  390 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  391 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  392 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  393 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  394 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  395 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  396 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  397 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  398 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  399 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  400 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  401 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  402 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  403 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  404 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  405 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  406 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  407 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  408 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  409 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  410 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  411 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  412 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  413 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  414 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  415 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  416 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  417 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  418 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  419 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  420 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  421 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  422 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  423 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  424 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  425 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  426 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  427 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  428 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  429 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  430 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  431 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  432 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  433 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  434 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  435 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  436 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  437 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  438 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  439 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  440 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  441 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  442 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  443 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  444 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  445 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  446 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  447 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  448 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  449 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  450 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  451 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  452 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  453 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  454 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  455 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  456 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  457 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  458 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  459 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  460 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  461 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  462 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  463 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  464 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  465 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  466 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  467 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  468 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  469 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  470 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  471 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  472 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  473 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  474 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  475 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  476 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  477 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  478 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  479 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  480 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  481 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  482 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  483 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  484 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  485 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  486 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  487 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  488 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  489 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  490 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  491 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  492 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  493 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  494 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  495 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  496 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  497 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  498 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  499 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  500 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  501 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  502 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  503 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  504 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  505 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  506 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  507 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  508 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  509 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  510 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  511 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  512 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  513 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  514 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  515 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  516 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  517 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  518 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  519 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  520 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  521 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  522 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  523 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  524 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  525 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  526 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  527 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  528 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  529 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  530 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  531 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  532 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  533 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  534 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  535 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  536 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  537 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  538 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  539 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  540 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  541 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  542 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  543 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  544 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  545 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  546 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  547 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  548 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  549 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  550 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  551 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  552 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  553 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  554 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  555 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  556 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  557 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  558 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  559 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  560 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  561 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  562 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  563 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  564 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  565 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  566 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  567 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  568 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  569 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  570 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  571 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  572 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  573 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  574 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  575 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  576 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  577 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  578 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  579 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  580 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  581 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  582 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  583 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  584 out of  586  trajectories
# (4, 2)
# Processed trajectory number :  585 out of  586  trajectories
# Total mean error of the model is  7.591804411203197

# %%
#linnear predictor
def linnear_pred(vec, n_pred):
  step = (vec[len(vec)-1]-vec[0])/(len(vec)-1)
  traj_total = np.zeros((len(vec)+n_pred,2))
  traj_total[len(traj_total)-n_pred: len(traj_total)]=  np.array([vec[len(vec)-1]+step*i for i in range(1, n_pred+1)])
  traj_total[0:len(vec)] = vec
  return traj_total

data_loader = DataLoader(1, sample_args.pred_length + sample_args.obs_length, list(range(90,100)), True)

# Maintain the total_error until now
total_error_linnear = 0.
counter = 0.
j = 0
for b in range(data_loader.num_batches):
    # Get the source, target data for the next batch
    x, y, mean_std = data_loader.next_batch()
    mean_x = mean_std[0][0]
    std_x = mean_std[0][1]
    mean_y = mean_std[1][0]
    std_y = mean_std[1][1]
    traj_real = x[0]
    
    indexes = mean_std[2]
    
    # The observed part of the trajectory
    obs_traj = x[0][:sample_args.obs_length]
    
    # Get the complete trajectory with both the observed and the predicted part from the model
    complete_traj =linnear_pred(obs_traj,sample_args.pred_length)
    j+=1
    obs_traj = np.array(obs_traj)
    complete_traj[:,0] = complete_traj[:,0] *(std_x + 0.5) +mean_x
    complete_traj[:,1] = complete_traj[:,1] *(std_y + 0.5) + mean_y
    
    traj_real[:,0] = traj_real[:,0] *(std_x + 0.5) + mean_x
    traj_real[:,1] = traj_real[:,1] *(std_y + 0.5) + mean_y
    
   
    # Compute the mean error between the predicted part and the true trajectory
    error = get_mean_error(complete_traj, traj_real, sample_args.obs_length)
    total_error_linnear += get_mean_error(complete_traj, traj_real, sample_args.obs_length)
    #print("Processed trajectory number : ", b, "out of ", data_loader.num_batches, " trajectories")
    
    if(j <10): #for the first 10 test partitions, let´s see the predicted trajectory, the real one, and the error
      print(complete_traj)
      print(map_data_split[indexes[0]+90, indexes[1]][indexes[2]])
      print(error)
# Print the mean error across all the batches
print("Total mean error of the model is ", total_error_linnear/data_loader.num_batches)
# Out:
# Creating pre-processed data from raw data
# [[5332.59       9050.51      ]
#  [5332.59       9050.48      ]
#  [5332.6        9050.45      ]
#  [5332.64       9050.28      ]
#  [5332.65666667 9050.20333333]
#  [5332.67333333 9050.12666667]
#  [5332.69       9050.05      ]]
# [[5332.59 9050.51]
#  [5332.59 9050.48]
#  [5332.6  9050.45]
#  [5332.64 9050.28]
#  [5332.68 9050.12]
#  [5332.72 9049.95]
#  [5332.77 9049.79]
#  [5332.81 9049.62]
#  [5332.85 9049.46]
#  [5332.89 9049.29]]
# 0.18043134813418846
# [[5320.65       9412.93      ]
#  [5316.79       9412.78      ]
#  [5314.21       9412.2       ]
#  [5311.7        9411.36      ]
#  [5308.71666667 9410.83666667]
#  [5305.73333333 9410.31333333]
#  [5302.75       9409.79      ]]
# [[5320.65 9412.93]
#  [5316.79 9412.78]
#  [5314.21 9412.2 ]
#  [5311.7  9411.36]
#  [5309.72 9410.35]
#  [5306.17 9410.33]
#  [5304.69 9410.75]
#  [5303.21 9411.18]
#  [5303.49 9410.81]
#  [5303.61 9410.61]]
# 1.2388833915515507
# [[12228.14       10254.66      ]
#  [12268.42       10283.36      ]
#  [12310.76       10314.48      ]
#  [12349.49       10342.07      ]
#  [12389.94       10371.20666667]
#  [12430.39       10400.34333333]
#  [12470.84       10429.48      ]]
# [[12228.14 10254.66]
#  [12268.42 10283.36]
#  [12310.76 10314.48]
#  [12349.49 10342.07]
#  [12390.11 10370.96]
#  [12432.2  10401.8 ]
#  [12470.91 10429.37]
#  [12510.25 10457.39]
#  [12549.6  10485.4 ]
#  [12592.76 10516.04]]
# 0.9177708911426515
# [[13160.08       10843.95      ]
#  [13157.23       10841.27      ]
#  [13154.82       10839.58      ]
#  [13153.09       10838.14      ]
#  [13150.76       10836.20333333]
#  [13148.43       10834.26666667]
#  [13146.1        10832.33      ]]
# [[13160.08 10843.95]
#  [13157.23 10841.27]
#  [13154.82 10839.58]
#  [13153.09 10838.14]
#  [13151.11 10836.18]
#  [13149.26 10834.57]
#  [13147.08 10833.38]
#  [13145.35 10832.19]
#  [13145.23 10831.66]
#  [13144.31 10830.37]]
# 0.8902495278965578
# [[14965.29 12574.94]
#  [14991.18 12597.71]
#  [15016.47 12621.16]
#  [15041.76 12644.6 ]
#  [15067.25 12667.82]
#  [15092.74 12691.04]
#  [15118.23 12714.26]]
# [[14965.29 12574.94]
#  [14991.18 12597.71]
#  [15016.47 12621.16]
#  [15041.76 12644.6 ]
#  [15067.04 12668.04]
#  [15092.33 12691.49]
#  [15117.24 12714.84]
#  [15142.15 12738.19]
#  [15167.06 12761.54]
#  [15191.98 12784.89]]
# 0.6867652385032982
# [[14584.77       12498.99      ]
#  [14584.77       12498.99      ]
#  [14585.01       12499.16      ]
#  [14585.24       12499.33      ]
#  [14585.39666667 12499.44333333]
#  [14585.55333333 12499.55666667]
#  [14585.71       12499.67      ]]
# [[14584.77 12498.99]
#  [14584.77 12498.99]
#  [14585.01 12499.16]
#  [14585.24 12499.33]
#  [14584.31 12498.65]
#  [14582.45 12497.31]
#  [14585.94 12499.83]
#  [14585.64 12499.19]
#  [14584.69 12498.4 ]
#  [14581.93 12496.3 ]]
# 1.818945320566624
# [[4979.15       9421.19      ]
#  [4979.15       9421.19      ]
#  [4979.1        9420.88      ]
#  [4979.12       9421.05      ]
#  [4979.11       9421.00333333]
#  [4979.1        9420.95666667]
#  [4979.09       9420.91      ]]
# [[4979.15 9421.19]
#  [4979.15 9421.19]
#  [4979.1  9420.88]
#  [4979.12 9421.05]
#  [4979.12 9421.05]
#  [4978.13 9419.82]
#  [4978.77 9419.61]
#  [4978.77 9419.61]
#  [4978.43 9419.67]
#  [4978.89 9419.59]]
# 0.9602747848026999
# [[15813.69       13131.67      ]
#  [15813.29       13131.35      ]
#  [15812.89       13131.03      ]
#  [15812.49       13130.7       ]
#  [15812.09       13130.37666667]
#  [15811.69       13130.05333333]
#  [15811.29       13129.73      ]]
# [[15813.69 13131.67]
#  [15813.29 13131.35]
#  [15812.89 13131.03]
#  [15812.49 13130.7 ]
#  [15811.76 13130.13]
#  [15811.04 13129.55]
#  [15810.32 13128.97]
#  [15809.6  13128.39]
#  [15808.55 13127.55]
#  [15807.51 13126.72]]
# 0.8221241492125587
# [[13218.16       10660.2       ]
#  [13223.36       10656.4       ]
#  [13228.44       10652.43      ]
#  [13232.24       10648.27      ]
#  [13236.93333333 10644.29333333]
#  [13241.62666667 10640.31666667]
#  [13246.32       10636.34      ]]
# [[13218.16 10660.2 ]
#  [13223.36 10656.4 ]
#  [13228.44 10652.43]
#  [13232.24 10648.27]
#  [13235.75 10643.85]
#  [13238.95 10639.2 ]
#  [13241.82 10634.34]
#  [13246.53 10624.09]
#  [13248.34 10618.75]
#  [13248.86 10613.71]]
# 3.029446635767824
# Total mean error of the model is  6.299264095742412

# %%
#Future: 

#We now have a working LSTM model. 

#LSTM social: 
#There is not a lot of social interactions in the dataset...

#Get to work socal LSTM, with social tensor = 0 (just with trajectory data it should work)
#Use social LSTM with social tensor. Probably results wont really improve


#Note LSTM model works slightly worse (almost identically) as the linnear predictor.
#the reason behind this could be the trajectory of the instances in the dataset largely depends on linnear behaviours
